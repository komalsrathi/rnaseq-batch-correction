# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import pip

tmbscorefile = "/Users/kogantit/Documents/TMB/PNOC003_analysis/all_PONOC003.tmb.txt"

#########################################################################
#########  Preparing input file #########################################

# Reading input file into pandas
tmb_scores_df = pd.read_csv(tmbscorefile, sep="\t")



median_width = 0.6
# Defining figure size
plt.figure(figsize=(20, 10))
# This plots all the disease types
ax = sns.stripplot(
    x="project",
    y="TMB",
    data=tmb_scores_df,
    jitter=1,
    linewidth=0.5,
)

# %%
tmb_scores_df.dtypes
# Out:
# Samplename               object
# experimental_strategy    object
# disease                  object
# count                    object
# bedlength                object
# TMB                      object
# project                  object
# dtype: object

# %%
tmb_scores_df["TMB"]=tmb_scores_df["TMB"].astype(float, copy=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-905a5a75df5c> in <module>
# ----> 1 tmb_scores_df["TMB"]=tmb_scores_df["TMB"].astype(float, copy=False)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...
